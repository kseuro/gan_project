# %%
# Dependencies
import torch
from torch import nn, optim
from torch.autograd.variable import Variable
from torchvision import transforms, datasets

# Visualization
from utils import Logger
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-44c8eb8dc914> in <module>
#       6
#       7 # Visualization
# ----> 8 from utils import Logger
#
# ~/Kai/deeplearnphysics/pytorch/GAN_project/gans_from_scratch_tutorial/utils.py in <module>
#       3 import errno
#       4 import torchvision.utils as vutils
# ----> 5 from tensorboardX import SummaryWriter
#       6 from IPython import display
#       7 from matplotlib import pyplot as plt
#
# ~/.local/lib/python3.5/site-packages/tensorboardX/__init__.py in <module>
#       3
#       4 from .record_writer import RecordWriter
# ----> 5 from .torchvis import TorchVis
#       6 from .writer import FileWriter, SummaryWriter
#
# ~/.local/lib/python3.5/site-packages/tensorboardX/torchvis.py in <module>
#       9
#      10 from functools import wraps
# ---> 11 from .writer import SummaryWriter
#      12 from .visdom_writer import VisdomWriter
#      13
#
# ~/.local/lib/python3.5/site-packages/tensorboardX/writer.py in <module>
#      25
#      26 from .embedding import make_mat, make_sprite, make_tsv, append_pbtxt
# ---> 27 from .event_file_writer import EventFileWriter
#      28 from .onnx_graph import gg
#      29 from .pytorch_graph import graph
#
# ~/.local/lib/python3.5/site-packages/tensorboardX/event_file_writer.py in <module>
#      26 import six
#      27
# ---> 28 from .proto import event_pb2
#      29 from .record_writer import RecordWriter, directory_check
#      30
#
# ~/.local/lib/python3.5/site-packages/tensorboardX/proto/event_pb2.py in <module>
#      13
#      14
# ---> 15 from tensorboardX.proto import summary_pb2 as tensorboardX_dot_proto_dot_summary__pb2
#      16
#      17
#
# ~/.local/lib/python3.5/site-packages/tensorboardX/proto/summary_pb2.py in <module>
#      13
#      14
# ---> 15 from tensorboardX.proto import tensor_pb2 as tensorboardX_dot_proto_dot_tensor__pb2
#      16
#      17
#
# ~/.local/lib/python3.5/site-packages/tensorboardX/proto/tensor_pb2.py in <module>
#      13
#      14
# ---> 15 from tensorboardX.proto import resource_handle_pb2 as tensorboardX_dot_proto_dot_resource__handle__pb2
#      16 from tensorboardX.proto import tensor_shape_pb2 as tensorboardX_dot_proto_dot_tensor__shape__pb2
#      17 from tensorboardX.proto import types_pb2 as tensorboardX_dot_proto_dot_types__pb2
#
# ~/.local/lib/python3.5/site-packages/tensorboardX/proto/resource_handle_pb2.py in <module>
#      20   syntax='proto3',
#      21   serialized_options=_b('\n\030org.tensorflow.frameworkB\016ResourceHandleP\001\370\001\001'),
# ---> 22   serialized_pb=_b('\n(tensorboardX/proto/resource_handle.proto\x12\x0ctensorboardX\"r\n\x13ResourceHandleProto\x12\x0e\n\x06\x64\x65vice\x18\x01 \x01(\t\x12\x11\n\tcontainer\x18\x02 \x01(\t\x12\x0c\n\x04name\x18\x03 \x01(\t\x12\x11\n\thash_code\x18\x04 \x01(\x04\x12\x17\n\x0fmaybe_type_name\x18\x05 \x01(\tB/\n\x18org.tensorflow.frameworkB\x0eResourceHandleP\x01\xf8\x01\x01\x62\x06proto3')
#      23 )
#      24
#
# TypeError: __new__() got an unexpected keyword argument 'serialized_options'

# %%
# Dataset
def mnist_data():
    compose = transforms.Compose( [transforms.ToTensor(),
                                   transforms.Normalize( (.5, .5, .5), (.5, .5, .5))
                                  ])
    out_dir = './mnist_dataset'
    return datasets.MNIST(root = out_dir, train = True, transform = compose, download = True)

# Load Data
data = mnist_data()

# Create loader with data - iterable object
data_loader = torch.utils.data.DataLoader(data, batch_size = 100, shuffle = True)

# Number of batches
num_batches = len(data_loader)

# Functionality
def img_to_vec(img):
    return images.view(images.size(0), 784)

def vec_to_img(vec):
    return  vectors.view(vectors.size(0), 1, 28, 28)

def noise(size):
    """
    Creates 1D vector of gaussian noise
    """
    n = Variable(torch.randn(size, 100))
    return n

def ones_target(size):
    """
    Tensor containing ones. Shape = size
    """
    ones = Variable(torch.ones(size, 1))
    return ones

def zeros_target(size)
    """
    Tensor containing zeroes. Shape = size
    """
    zeros = Variable(torch.zeros(size,1))
    return zeros

# Optimization
d_optim = optim.Adam(DNet.parameters(), lr = 2e-4)
g_optim = optim.Adam(GNet.parameters(), lr = 2e-4)

# Loss Function
loss_fn = nn.BCELoss()

# %%
# Discriminator
# Input = Flattened images of dataset
# Returns = Prob. of input belonging to dataset

# Architecture: 3 hidden layers with LReLU & Dropout -- sigmoid applied to output

class DNet(torch.nn.Module):
    def __init__(self):
        super(DNet, self).__init__()
        n_features = 784 # 28x28 input image = 784 flat vector
        n_out = 1
        
        self.hidden0 = nn.Sequential(
            nn.Linear(n_features, 1024), nn.LeakyReLU(0.2), nn.Dropout(0.3)
        )
        self.hidden1 = nn.Sequential(
            nn.Linear(1024, 512), nn.LeakyReLU(0.2), nn.Dropout(0.3)
        )
        self.hidden2 = nn.Sequential(
            nn.Linear(512, 256), nn.LeakyReLU(0.2), nn.Dropout(0.3)
        )
        self.out = nn.Sequential(
            nn.Linear(256, n_out), nn.Sigmoid()
        )
        
        def forward(self, x):
            x = self.hidden0(x)
            x = self.hidden1(x)
            x = self.hidden2(x)
            x = self.out(x)
            
            return x
        
DNet = DNet()

# %%
class GNet(torch.nn.Module):
    def __init__(self):
        super(GNet, self).__init__()
        n_features = 100
        n_out = 784
        
        self.hidden0 = nn.Sequential(
            nn.Linear(n_features, 256), nn.LeakyReLU(0.2)
        )
        self.hidden1 = nn.Sequential(
            nn.Linear(256, 512), nn.LeakyReLU(0.2)
        )
        self.hidden2 = nn.Sequential(
            nn.Linear(512, 1024), nn.LeakyReLU(0.2)
        )
        self.out = nn.Sequential(
            nn.Linear(1024, n_out), nn.Tanh()
        )
        
    def forward(self, x):
        x = self.hidden0(x)
        x = self.hidden1(x)
        x = self.hidden2(x)
        x = self.out(x)

        return x
    
GNet = GNet()

# %%
def train_DNet(optimizer, real_data, G_data):
    N = real_data.size(0)
    optimizer.zero_grad() # Reset gradients
    
    # 1.1 Train on Real Data
    pred_real = DNet(real_data)
    error_real = loss(pred_real, ones_target(N)) # Calc error
    error_real.backward() # Backprop
    
    # 1.2 Train on Fake Data
    pred_fake = DNet(fake_data)
    error_fake = loss(pred_fake, zeros_target(N)) # calc error
    error_fake.backward() # backprop
    
    # Update weights with gradients
    optimizer.step()
    
    # Return error and preds for real and fake inputs
    return error_real + error_fake, pred_real, pred_fake

def train_GNet(optimizer, fake_data):
    N = fake_data.size(0)
    optimizer.zero_grad() # Reset gradients
    
    # Sample noise and gen fake data
    pred = DNet(fake_data)
    
    # Calc error and backprop
    error = loss(pred, ones_target(N))
    error.backward()
    
    # Update weights with gradients
    optimizer.step()
    
    # Return error
    return error

# %%
# Test generator every few steps
num_test_samples = 16
test_noise = noise(num_test_samples)

# Training
# Create logger instance
logger = Logger(model_name = "Test_GAN", data_name = "MNIST")

# Total number of training epochs
num_epochs = 200

for epoch in range(num_epochs):
    for n_batch, (real_batch, _ ) in enumerate(data_loader):
        N = real_batch.size(0)
        
        # 1. Train DNet
        real_data = Variable(img_to_vec(real_batch))
        
        # Gen. fake data and detach
        # detach so that grad not calc'd for GNet
        fake_data = generator(noise(N)).detach()
        
        # Train D
        D_error, D_pred_real, D_pred_fake = \
            train_DNet(d_optim, real_data, fake_data)
        
        # Train GNet
        # Gen fake data
        fake_data = GNet(noise(N))
        
        # Train G
        G_error = train_GNet(g_optim, fake_data)
        
        # Log batch error
        logger.log(d_error, g_error, epoch, n_batch, num_batches)
        
        # Disp. progress every few batches
        if n_batch % 100 == 0:
            test_images = vec_to_img(GNet(test_noise))
            test_images = test_images.data
            
            logger.log_images(
                test_images, num_test_samples, epoch, n_batch, num_batches
            )
            # Disp status logs
            logger.display_status(
                epoch, num_epochs, n_batch, num_batches, D_error, G_error,
                d_pred_real, d_pred_fake
            )
# Out:
#   File "<ipython-input-16-059454760ca7>", line 14
#
#     ^
# SyntaxError: unexpected EOF while parsing
